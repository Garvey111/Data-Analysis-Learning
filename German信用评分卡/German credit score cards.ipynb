# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
matplotlib.rc("font", family='Microsoft YaHei')
plt.rcParams["font.sans-serif"]=['SimHei']
plt.rcParams["axes.unicode_minus"]=False
plt.rcParams.update({'font.size':13 }) #全局字体大小
plt.rcParams["font.family"]=['SimHei']
plt.rcParams['axes.unicode_minus']=False

# %%
column = ['账户状态','续存期数','信用记录','目的','信用额度','储蓄情况',
          '工作年限','分期利率','性别及婚姻情况','担保情况','现居时间',
          '财产情况','年龄','其他分期计划','住房','信用卡数量','工作状况',
          '法人数量','是否有电话','外籍工作者','违约']

# %%
df = pd.read_csv('./数据/german.data',sep=' ',header=None)
df.columns = column
df
# Out:
#     账户状态  续存期数 信用记录   目的  信用额度 储蓄情况 工作年限  分期利率 性别及婚姻情况  担保情况  ...  财产情况  年龄  \
# 0    A11     6  A34  A43  1169  A65  A75     4     A93  A101  ...  A121  67
# 1    A12    48  A32  A43  5951  A61  A73     2     A92  A101  ...  A121  22
# 2    A14    12  A34  A46  2096  A61  A74     2     A93  A101  ...  A121  49
# 3    A11    42  A32  A42  7882  A61  A74     2     A93  A103  ...  A122  45
# 4    A11    24  A33  A40  4870  A61  A73     3     A93  A101  ...  A124  53
# ..   ...   ...  ...  ...   ...  ...  ...   ...     ...   ...  ...   ...  ..
# 995  A14    12  A32  A42  1736  A61  A74     3     A92  A101  ...  A121  31
# 996  A11    30  A32  A41  3857  A61  A73     4     A91  A101  ...  A122  40
# 997  A14    12  A32  A43   804  A61  A75     4     A93  A101  ...  A123  38
# 998  A11    45  A32  A43  1845  A61  A73     4     A93  A101  ...  A124  23
# 999  A12    45  A34  A41  4576  A62  A71     3     A93  A101  ...  A123  27
#
#      其他分期计划    住房 信用卡数量  工作状况 法人数量  是否有电话 外籍工作者 违约
# 0      A143  A152     2  A173    1   A192  A201  1
# 1      A143  A152     1  A173    1   A191  A201  2
# 2      A143  A152     1  A172    2   A191  A201  1
# 3      A143  A153     1  A173    2   A191  A201  1
# 4      A143  A153     2  A173    2   A191  A201  2
# ..      ...   ...   ...   ...  ...    ...   ... ..
# 995    A143  A152     1  A172    1   A191  A201  1
# 996    A143  A152     1  A174    1   A192  A201  1
# 997    A143  A152     1  A173    1   A191  A201  1
# 998    A143  A153     1  A173    1   A192  A201  2
# 999    A143  A152     1  A173    1   A191  A201  1
#
# [1000 rows x 21 columns]

# %%
#将'逾期'标签变量转为0，1（0：好；1：差）
df['违约'] = df['违约']-1
df
# Out:
#     账户状态  续存期数 信用记录   目的  信用额度 储蓄情况 工作年限  分期利率 性别及婚姻情况  担保情况  ...  财产情况  年龄  \
# 0    A11     6  A34  A43  1169  A65  A75     4     A93  A101  ...  A121  67
# 1    A12    48  A32  A43  5951  A61  A73     2     A92  A101  ...  A121  22
# 2    A14    12  A34  A46  2096  A61  A74     2     A93  A101  ...  A121  49
# 3    A11    42  A32  A42  7882  A61  A74     2     A93  A103  ...  A122  45
# 4    A11    24  A33  A40  4870  A61  A73     3     A93  A101  ...  A124  53
# ..   ...   ...  ...  ...   ...  ...  ...   ...     ...   ...  ...   ...  ..
# 995  A14    12  A32  A42  1736  A61  A74     3     A92  A101  ...  A121  31
# 996  A11    30  A32  A41  3857  A61  A73     4     A91  A101  ...  A122  40
# 997  A14    12  A32  A43   804  A61  A75     4     A93  A101  ...  A123  38
# 998  A11    45  A32  A43  1845  A61  A73     4     A93  A101  ...  A124  23
# 999  A12    45  A34  A41  4576  A62  A71     3     A93  A101  ...  A123  27
#
#      其他分期计划    住房 信用卡数量  工作状况 法人数量  是否有电话 外籍工作者 违约
# 0      A143  A152     2  A173    1   A192  A201  0
# 1      A143  A152     1  A173    1   A191  A201  1
# 2      A143  A152     1  A172    2   A191  A201  0
# 3      A143  A153     1  A173    2   A191  A201  0
# 4      A143  A153     2  A173    2   A191  A201  1
# ..      ...   ...   ...   ...  ...    ...   ... ..
# 995    A143  A152     1  A172    1   A191  A201  0
# 996    A143  A152     1  A174    1   A192  A201  0
# 997    A143  A152     1  A173    1   A191  A201  0
# 998    A143  A153     1  A173    1   A192  A201  1
# 999    A143  A152     1  A173    1   A191  A201  0
#
# [1000 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   账户状态     1000 non-null   object
#  1   续存期数     1000 non-null   int64
#  2   信用记录     1000 non-null   object
#  3   目的       1000 non-null   object
#  4   信用额度     1000 non-null   int64
#  5   储蓄情况     1000 non-null   object
#  6   工作年限     1000 non-null   object
#  7   分期利率     1000 non-null   int64
#  8   性别及婚姻情况  1000 non-null   object
#  9   担保情况     1000 non-null   object
#  10  现居时间     1000 non-null   int64
#  11  财产情况     1000 non-null   object
#  12  年龄       1000 non-null   int64
#  13  其他分期计划   1000 non-null   object
#  14  住房       1000 non-null   object
#  15  信用卡数量    1000 non-null   int64
#  16  工作状况     1000 non-null   object
#  17  法人数量     1000 non-null   int64
#  18  是否有电话    1000 non-null   object
#  19  外籍工作者    1000 non-null   object
#  20  违约       1000 non-null   int64
# dtypes: int64(8), object(13)
# memory usage: 164.2+ KB

# %%
sns.histplot(data = df['违约'],x=df['违约'].values,binwidth=0.4)
plt.xticks(ticks=[0,1],labels=['0','1'])
plt.xlabel('违约')
plt.show()

# %%
#数值型变量
numerical = list(df.describe().columns)
#类别型变量
category = list(set(column)-set(numerical))

# %%
df_numerical = df.loc[:,numerical]
df_numerical.head()
# Out:
#    续存期数  信用额度  分期利率  现居时间  年龄  信用卡数量  法人数量  违约
# 0     6  1169     4     4  67      2     1   0
# 1    48  5951     2     2  22      1     1   1
# 2    12  2096     2     3  49      1     2   0
# 3    42  7882     2     4  45      1     2   0
# 4    24  4870     3     4  53      2     2   1

# %%
category.append('违约')
df_category = df.loc[:,category]
df_category
# Out:
#     是否有电话 其他分期计划  工作状况 外籍工作者 账户状态 工作年限 储蓄情况    住房  财产情况 性别及婚姻情况 信用记录  担保情况  \
# 0    A192   A143  A173  A201  A11  A75  A65  A152  A121     A93  A34  A101
# 1    A191   A143  A173  A201  A12  A73  A61  A152  A121     A92  A32  A101
# 2    A191   A143  A172  A201  A14  A74  A61  A152  A121     A93  A34  A101
# 3    A191   A143  A173  A201  A11  A74  A61  A153  A122     A93  A32  A103
# 4    A191   A143  A173  A201  A11  A73  A61  A153  A124     A93  A33  A101
# ..    ...    ...   ...   ...  ...  ...  ...   ...   ...     ...  ...   ...
# 995  A191   A143  A172  A201  A14  A74  A61  A152  A121     A92  A32  A101
# 996  A192   A143  A174  A201  A11  A73  A61  A152  A122     A91  A32  A101
# 997  A191   A143  A173  A201  A14  A75  A61  A152  A123     A93  A32  A101
# 998  A192   A143  A173  A201  A11  A73  A61  A153  A124     A93  A32  A101
# 999  A191   A143  A173  A201  A12  A71  A62  A152  A123     A93  A34  A101
#
#       目的  违约
# 0    A43   0
# 1    A43   1
# 2    A46   0
# 3    A42   0
# 4    A40   1
# ..   ...  ..
# 995  A42   0
# 996  A41   0
# 997  A43   0
# 998  A43   1
# 999  A41   0
#
# [1000 rows x 14 columns]

# %%
#df_numerical[df_numerical['逾期']==0][['期数']]
#df_numerical[df_numerical['逾期']==1][['期数']]

# %%
#类别型变量
plt.figure(figsize=(23,20))
i=1
for temp in category[:-1]:
    plt.subplot(4,4,i)
    sns.countplot(data=df_category,x=temp,hue='违约')
    i+=1      
plt.show()

# %%
#数值型变量分布（直方图）
plt.figure(figsize=(20,20))
i=1
for temp in numerical[:-1]:
    plt.subplot(4,2,i)
    sns.histplot(data = df_numerical,x=temp,hue='违约')
    i+=1      
plt.show()

# %%
#数值型变量分布(箱线图)
plt.figure(figsize=(18,24))
i=1
for temp in numerical[:-1]:
    plt.subplot(4,2,i)
    sns.boxenplot(data = df_numerical,y=temp,x='违约')
    plt.title(f'{temp} 和 违约 的箱线图')
    i+=1      
plt.show()

# %%
df_numerical.describe()
# Out:
#               续存期数          信用额度         分期利率         现居时间           年龄  \
# count  1000.000000   1000.000000  1000.000000  1000.000000  1000.000000
# mean     20.903000   3271.258000     2.973000     2.845000    35.546000
# std      12.058814   2822.736876     1.118715     1.103718    11.375469
# min       4.000000    250.000000     1.000000     1.000000    19.000000
# 25%      12.000000   1365.500000     2.000000     2.000000    27.000000
# 50%      18.000000   2319.500000     3.000000     3.000000    33.000000
# 75%      24.000000   3972.250000     4.000000     4.000000    42.000000
# max      72.000000  18424.000000     4.000000     4.000000    75.000000
#
#              信用卡数量         法人数量           违约
# count  1000.000000  1000.000000  1000.000000
# mean      1.407000     1.155000     0.300000
# std       0.577654     0.362086     0.458487
# min       1.000000     1.000000     0.000000
# 25%       1.000000     1.000000     0.000000
# 50%       1.000000     1.000000     0.000000
# 75%       2.000000     1.000000     1.000000
# max       4.000000     2.000000     1.000000

# %%
#df['价格等级'] = pd.cut(df['价格'],[0,500,10000,100000],labels=['C','B','A'])

# %%
df.describe()
# Out:
#               续存期数          信用额度         分期利率         现居时间           年龄  \
# count  1000.000000   1000.000000  1000.000000  1000.000000  1000.000000
# mean     20.903000   3271.258000     2.973000     2.845000    35.546000
# std      12.058814   2822.736876     1.118715     1.103718    11.375469
# min       4.000000    250.000000     1.000000     1.000000    19.000000
# 25%      12.000000   1365.500000     2.000000     2.000000    27.000000
# 50%      18.000000   2319.500000     3.000000     3.000000    33.000000
# 75%      24.000000   3972.250000     4.000000     4.000000    42.000000
# max      72.000000  18424.000000     4.000000     4.000000    75.000000
#
#              信用卡数量         法人数量           违约
# count  1000.000000  1000.000000  1000.000000
# mean      1.407000     1.155000     0.300000
# std       0.577654     0.362086     0.458487
# min       1.000000     1.000000     0.000000
# 25%       1.000000     1.000000     0.000000
# 50%       1.000000     1.000000     0.000000
# 75%       2.000000     1.000000     1.000000
# max       4.000000     2.000000     1.000000

# %% [markdown]
# ### 数值型连续变量分箱处理
# 依据参考上述分布图

# %%
# 数值型变量的等距分箱
def binning_num(df,target,col_list,n=10):
    """
    df:数据集
    target:目标变量的字段名
    col_list:变量list集合
    n:分箱个数 默认为10
    return:
    iv_value:list形式，里面存储每个变量的IV值
    """
    total = df[target].count()
    bad = df[target].sum() #计数违约为1
    good = total-bad       #总数-违约的
    iv_value=[]
    bucket=0
    for col in col_list:
        bucket = pd.cut(df[col],n) #分箱操作
        d1 = df.groupby(bucket)   #按照分箱进行分组
        d2 = pd.DataFrame()       #构造dataframe
        d2['min_bin'] = d1[col].min()  #最小值
        d2['max_bin'] = d1[col].max()  #最大值
        d2['total'] = d1[target].count()  #目标变量分组汇总数
        d2['totalrate'] = d2['total']/total 
        d2['bad'] = d1[target].sum()
        d2['badrate'] = d2['bad']/d2['total']
        d2['good'] = d2['total'] - d2['bad']
        d2['goodrate'] = d2['good']/d2['total']   
        d2['badattr'] = d2['bad']/bad                    #bad%
        d2['goodattr'] = (d2['total']-d2['bad'])/good    #good%   
        d2['woe'] = np.log(d2['badattr']/d2['goodattr'])
        d2['bin_iv'] = (d2['badattr']-d2['goodattr'])*d2['woe']
        d2['IV'] = d2['bin_iv'].sum()
        iv = d2['bin_iv'].sum().round(4)      
        iv_value.append(iv)
        
    return iv_value

# %%
temp = df

# %%
#续存期数
iv = []
x = []
for i in range(1,5):
    iv.append(binning_num(df.loc[:,['续存期数','违约']],target='违约',n=i,col_list=['续存期数'])[0])  
    x.append(i)
plt.plot(x,iv)
plt.xticks(range(1,6))
plt.ylabel('IV值')
plt.xlabel('number of box')
plt.show()

# %%
pd.cut(df['续存期数'],4).unique()
# Out:
# [(3.932, 21.0], (38.0, 55.0], (21.0, 38.0], (55.0, 72.0]]
# Categories (4, interval[float64, right]): [(3.932, 21.0] < (21.0, 38.0] < (38.0, 55.0] < (55.0, 72.0]]

# %% [markdown]
# #### 1、续存期数：'0':0-20 ; '1':20-40  ;  '2':40-55 ; '3':55以上

# %%
df['续存期数'] = pd.cut(df['续存期数'],[0,20,40,55,75],labels=['0','1','2','3'])

# %%
#信用额度
iv = []
x = []
for i in range(1,8):
    iv.append(binning_num(df.loc[:,['信用额度','违约']],target='违约',n=i,col_list=['信用额度'])[0])   
    x.append(i)
plt.plot(x,iv)
plt.xticks(range(1,8))
plt.ylabel('IV值')
plt.xlabel('number of box')
plt.show()

# %%
pd.cut(df['信用额度'],5).unique()
# Out:
# [(231.826, 3884.8], (3884.8, 7519.6], (7519.6, 11154.4], (11154.4, 14789.2], (14789.2, 18424.0]]
# Categories (5, interval[float64, right]): [(231.826, 3884.8] < (3884.8, 7519.6] < (7519.6, 11154.4] < (11154.4, 14789.2] < (14789.2, 18424.0]]

# %% [markdown]
# #### 2、信用额度:'0':0-4000 ; '1':4000-8000 ; '2':8000-12000 ; '3':12000-15000 ; '4':15000以上

# %%
df['信用额度'] = pd.cut(df['信用额度'],[0,4000,8000,12000,15000,19000],labels=['0','1','2','3','4'])

# %% [markdown]
# #### 3、分期利率:只有[4, 2, 3, 1]四种利率，直接转为字符串进行分箱

# %%
df['分期利率'] = df['分期利率'].astype('object')

# %% [markdown]
# #### 4、现居时间: 只有[4, 2, 3, 1]四种现居时间，直接转为字符串进行分箱

# %%
df['现居时间'] = df['现居时间'].astype('object')

# %%
#年龄
iv = []
x = []
for i in range(1,8):
    iv.append(binning_num(df.loc[:,['年龄','违约']],target='违约',n=i,col_list=['年龄'])[0])   
    x.append(i)
plt.plot(x,iv)
plt.xticks(range(1,8))
plt.ylabel('IV值')
plt.xlabel('number of box')
plt.show()

# %% [markdown]
# #### 5、年龄 '0':18-35 ; '1':35-50 ; '2':50-60 ; '3':60以上

# %%
df['年龄'] = pd.cut(df['年龄'],[18,35,50,60,80],labels=['0','1','2','3'])

# %% [markdown]
# #### 6、信用卡数量:只有[4, 2, 3, 1]四种信用卡数量，直接转为字符串进行分箱

# %%
df['信用卡数量'] = df['信用卡数量'].astype('object')

# %% [markdown]
# #### 7、法人数量: 只有[1,2]四种法人数量，直接转为字符串进行分箱

# %%
df['法人数量'] = df['法人数量'].astype('object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   账户状态     1000 non-null   object
#  1   续存期数     1000 non-null   category
#  2   信用记录     1000 non-null   object
#  3   目的       1000 non-null   object
#  4   信用额度     1000 non-null   category
#  5   储蓄情况     1000 non-null   object
#  6   工作年限     1000 non-null   object
#  7   分期利率     1000 non-null   object
#  8   性别及婚姻情况  1000 non-null   object
#  9   担保情况     1000 non-null   object
#  10  现居时间     1000 non-null   object
#  11  财产情况     1000 non-null   object
#  12  年龄       1000 non-null   category
#  13  其他分期计划   1000 non-null   object
#  14  住房       1000 non-null   object
#  15  信用卡数量    1000 non-null   object
#  16  工作状况     1000 non-null   object
#  17  法人数量     1000 non-null   object
#  18  是否有电话    1000 non-null   object
#  19  外籍工作者    1000 non-null   object
#  20  违约       1000 non-null   int64
# dtypes: category(3), int64(1), object(17)
# memory usage: 144.3+ KB

# %%
#对原本的类别型数据进行清洗，避免出现位符占位情况
df.loc[:,category[:-1]].applymap(lambda x:x.replace('\n','') )
df.loc[:,category[:-1]].applymap(lambda x:x.replace('\t','') )
df.loc[:,category[:-1]].applymap(lambda x:x.replace(' ','') )
# Out:
#     是否有电话 其他分期计划  工作状况 外籍工作者 账户状态 工作年限 储蓄情况    住房  财产情况 性别及婚姻情况 信用记录  担保情况  \
# 0    A192   A143  A173  A201  A11  A75  A65  A152  A121     A93  A34  A101
# 1    A191   A143  A173  A201  A12  A73  A61  A152  A121     A92  A32  A101
# 2    A191   A143  A172  A201  A14  A74  A61  A152  A121     A93  A34  A101
# 3    A191   A143  A173  A201  A11  A74  A61  A153  A122     A93  A32  A103
# 4    A191   A143  A173  A201  A11  A73  A61  A153  A124     A93  A33  A101
# ..    ...    ...   ...   ...  ...  ...  ...   ...   ...     ...  ...   ...
# 995  A191   A143  A172  A201  A14  A74  A61  A152  A121     A92  A32  A101
# 996  A192   A143  A174  A201  A11  A73  A61  A152  A122     A91  A32  A101
# 997  A191   A143  A173  A201  A14  A75  A61  A152  A123     A93  A32  A101
# 998  A192   A143  A173  A201  A11  A73  A61  A153  A124     A93  A32  A101
# 999  A191   A143  A173  A201  A12  A71  A62  A152  A123     A93  A34  A101
#
#       目的
# 0    A43
# 1    A43
# 2    A46
# 3    A42
# 4    A40
# ..   ...
# 995  A42
# 996  A41
# 997  A43
# 998  A43
# 999  A41
#
# [1000 rows x 13 columns]

# %%
col = list(df.columns)
#len(col[:-1])
#col[:-1]

# %%
# 备份df数据集
df_ = df.copy()
df_after = df.copy()

# %%
#将 woe 值替换进 df_after
def WOE_todf(varList,df,df_after): 
    '''
    varList：表示需要计算 WOE 并替换的变量列表，
    df即是存储对于目标变量和特征变量的数据集合，
    df_after:是把 woe值替换进去的数据集
    '''
    for var in varList:  #遍历varList
        data = df.groupby([var,'违约'])[['违约']].count().rename(columns={'违约':'数量'})
        data = data.reset_index()
        good_sum = data[data.违约==0]['数量'].sum()
        bad_sum = data[data.违约==1]['数量'].sum()
        woe = {}
        for i in df[var].unique():
            good_temp = data[(data[var]==i) & (data['违约']==0)]['数量'].sum()
            bad_temp = data[(data[var]==i) & (data['违约']==1)]['数量'].sum()
            woe[i] = np.log(((good_temp/good_sum)/(bad_temp/bad_sum)))  #woe值
                  
            #将对变量var分箱好的woe值替换回df数据集合,对woe值精确到4位并填入原数据集
            df_after.loc[:,[var]] = df_after.loc[:,[var]].replace(i,round(woe[i],4))  
             
    return df_after

# %%
def WOE(var,df):
    #var：表示需要计算 WOE和 IV值的变量，df即是存储对于目标变量和特征变量的数据集合
    data = df.groupby([var,'违约'])[['违约']].count().rename(columns={'违约':'数量'})
    data = data.reset_index()
    good_sum = data[data.违约==0]['数量'].sum()
    bad_sum = data[data.违约==1]['数量'].sum()
    woe = {}
    IV = 0
    for i in df[var].unique():
        good_temp = data[(data[var]==i) & (data['违约']==0)]['数量'].sum()
        bad_temp = data[(data[var]==i) & (data['违约']==1)]['数量'].sum()
        woe[i] = np.log(((good_temp/good_sum)/(bad_temp/bad_sum)))
        IV += ((good_temp/good_sum)-(bad_temp/bad_sum)) * woe[i]
           
    return woe,IV

# %%
def IV(var,df):      #var：表示需要计算 IV值的变量，df即是存储对于目标变量和特征变量的数据集合
    data = df.groupby([var,'违约'])[['违约']].count().rename(columns={'违约':'数量'})
    data = data.reset_index()
    good_sum = data[data.违约==0]['数量'].sum()
    bad_sum = data[data.违约==1]['数量'].sum()
    woe = {}
    IV = 0
    for i in df[var].unique():
        good_temp = data[(data[var]==i) & (data['违约']==0)]['数量'].sum()
        bad_temp = data[(data[var]==i) & (data['违约']==1)]['数量'].sum()
        woe[i] = np.log(((good_temp/good_sum)/(bad_temp/bad_sum)))
        IV += ((good_temp/good_sum)-(bad_temp/bad_sum)) * woe[i]
           
    return IV

# %%
#调用 WOE_todf 函数，输出将 woe 值替换完成的dataframe
df_after = WOE_todf(col[:-1],df_,df_after)
df_after
# Out:
#        账户状态    续存期数    信用记录      目的    信用额度    储蓄情况    工作年限    分期利率  性别及婚姻情况  \
# 0   -0.8181  0.3050  0.7337  0.4101  0.2059  0.7042  0.2356 -0.1573   0.1655
# 1   -0.4014 -0.9968 -0.0883  0.4101 -0.3606 -0.2714 -0.0321  0.1555  -0.2353
# 2    1.1763  0.3050  0.7337 -0.6061  0.2059 -0.2714  0.3944  0.1555   0.1655
# 3   -0.8181 -0.9968 -0.0883 -0.0956 -0.3606 -0.2714  0.3944  0.1555   0.1655
# 4   -0.8181 -0.1828 -0.0852 -0.3592 -0.3606 -0.2714 -0.0321  0.0645   0.1655
# ..      ...     ...     ...     ...     ...     ...     ...     ...      ...
# 995  1.1763  0.3050 -0.0883 -0.0956  0.2059 -0.2714  0.3944  0.0645  -0.2353
# 996 -0.8181 -0.1828 -0.0883  0.7738  0.2059 -0.2714 -0.0321 -0.1573  -0.4418
# 997  1.1763  0.3050 -0.0883  0.4101  0.2059 -0.2714  0.2356 -0.1573   0.1655
# 998 -0.8181 -0.9968 -0.0883  0.4101  0.2059 -0.2714 -0.0321 -0.1573   0.1655
# 999 -0.4014 -0.9968  0.7337  0.7738 -0.3606 -0.1396 -0.3192  0.0645   0.1655
#
#        担保情况  ...    财产情况      年龄  其他分期计划      住房   信用卡数量    工作状况    法人数量  \
# 0    0.0005  ...  0.4610  0.4055  0.1212  0.1942  0.1157  0.0228 -0.0028
# 1    0.0005  ...  0.4610 -0.1694  0.1212  0.1942 -0.0749  0.0228 -0.0028
# 2    0.0005  ...  0.4610  0.3194  0.1212  0.1942 -0.0749  0.0972  0.0154
# 3    0.5878  ... -0.0286  0.3194  0.1212 -0.4726 -0.0749  0.0228  0.0154
# 4    0.0005  ... -0.5861 -0.0417  0.1212 -0.4726  0.1157  0.0228  0.0154
# ..      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 995  0.0005  ...  0.4610 -0.1694  0.1212  0.1942 -0.0749  0.0972 -0.0028
# 996  0.0005  ... -0.0286  0.3194  0.1212  0.1942 -0.0749 -0.2044 -0.0028
# 997  0.0005  ... -0.0342  0.3194  0.1212  0.1942 -0.0749  0.0228 -0.0028
# 998  0.0005  ... -0.5861 -0.1694  0.1212 -0.4726 -0.0749  0.0228 -0.0028
# 999  0.0005  ... -0.0342 -0.1694  0.1212  0.1942 -0.0749  0.0228 -0.0028
#
#       是否有电话   外籍工作者  违约
# 0    0.0986 -0.0349   0
# 1   -0.0647 -0.0349   1
# 2   -0.0647 -0.0349   0
# 3   -0.0647 -0.0349   0
# 4   -0.0647 -0.0349   1
# ..      ...     ...  ..
# 995 -0.0647 -0.0349   0
# 996  0.0986 -0.0349   0
# 997 -0.0647 -0.0349   0
# 998  0.0986 -0.0349   1
# 999 -0.0647 -0.0349   0
#
# [1000 rows x 21 columns]

# %%
df
# Out:
#     账户状态 续存期数 信用记录   目的 信用额度 储蓄情况 工作年限 分期利率 性别及婚姻情况  担保情况  ...  财产情况 年龄  \
# 0    A11    0  A34  A43    0  A65  A75    4     A93  A101  ...  A121  3
# 1    A12    2  A32  A43    1  A61  A73    2     A92  A101  ...  A121  0
# 2    A14    0  A34  A46    0  A61  A74    2     A93  A101  ...  A121  1
# 3    A11    2  A32  A42    1  A61  A74    2     A93  A103  ...  A122  1
# 4    A11    1  A33  A40    1  A61  A73    3     A93  A101  ...  A124  2
# ..   ...  ...  ...  ...  ...  ...  ...  ...     ...   ...  ...   ... ..
# 995  A14    0  A32  A42    0  A61  A74    3     A92  A101  ...  A121  0
# 996  A11    1  A32  A41    0  A61  A73    4     A91  A101  ...  A122  1
# 997  A14    0  A32  A43    0  A61  A75    4     A93  A101  ...  A123  1
# 998  A11    2  A32  A43    0  A61  A73    4     A93  A101  ...  A124  0
# 999  A12    2  A34  A41    1  A62  A71    3     A93  A101  ...  A123  0
#
#     其他分期计划    住房 信用卡数量  工作状况 法人数量 是否有电话 外籍工作者 违约
# 0     A143  A152     2  A173    1  A192  A201  0
# 1     A143  A152     1  A173    1  A191  A201  1
# 2     A143  A152     1  A172    2  A191  A201  0
# 3     A143  A153     1  A173    2  A191  A201  0
# 4     A143  A153     2  A173    2  A191  A201  1
# ..     ...   ...   ...   ...  ...   ...   ... ..
# 995   A143  A152     1  A172    1  A191  A201  0
# 996   A143  A152     1  A174    1  A192  A201  0
# 997   A143  A152     1  A173    1  A191  A201  0
# 998   A143  A153     1  A173    1  A192  A201  1
# 999   A143  A152     1  A173    1  A191  A201  0
#
# [1000 rows x 21 columns]

# %%
#计算各变量的IV值，判断变量是否进入模型
iv_dict = {}  #iv集合
for k in col[:-1]:
    iv_dict[k] = IV(k,df)

# %%
#绘图
x = iv_dict.keys()
y=[]
for val in iv_dict.values():
    y.append(round(val,3))
plt.figure(figsize=(15,6))
ax = plt.subplot(1,1,1)
rects = ax.bar(x,y)
ax.bar_label(rects,padding=3)
plt.ylabel('IV值',fontsize=18)
plt.xlabel('特征变量',fontsize=18)
plt.title('IV值与特征变量柱状图')
plt.xticks(rotation=45)
plt.show()

# %%
#升序排序
lt = sorted(iv_dict.items(),key=lambda s:s[1])

# %%
#iv z值大于 0.08 的特征变量
lt = lt[-9:]
lt
# Out:
# [('住房', 0.08329343361549926),
#  ('工作年限', 0.086433631026641),
#  ('财产情况', 0.11263826240979673),
#  ('续存期数', 0.14760905122423662),
#  ('信用额度', 0.14792743500157343),
#  ('目的', 0.16919506567307835),
#  ('储蓄情况', 0.1960095569042267),
#  ('信用记录', 0.2932335473908263),
#  ('账户状态', 0.6660115033513336)]

# %%
tar = []
for a in range(len(lt)):
    tar.append(lt[a][0])
print(f"IV值大于0.08的变量：\n{tar},\n长度为：{len(tar)}")
# Out:
# IV值大于0.08的变量：
# ['住房', '工作年限', '财产情况', '续存期数', '信用额度', '目的', '储蓄情况', '信用记录', '账户状态'],
# 长度为：9

# %%
tar.append('违约')  #引入目标变量
df_info = df_after.loc[:,tar]
df_info
# Out:
#          住房    工作年限    财产情况    续存期数    信用额度      目的    储蓄情况    信用记录    账户状态  \
# 0    0.1942  0.2356  0.4610  0.3050  0.2059  0.4101  0.7042  0.7337 -0.8181
# 1    0.1942 -0.0321  0.4610 -0.9968 -0.3606  0.4101 -0.2714 -0.0883 -0.4014
# 2    0.1942  0.3944  0.4610  0.3050  0.2059 -0.6061 -0.2714  0.7337  1.1763
# 3   -0.4726  0.3944 -0.0286 -0.9968 -0.3606 -0.0956 -0.2714 -0.0883 -0.8181
# 4   -0.4726 -0.0321 -0.5861 -0.1828 -0.3606 -0.3592 -0.2714 -0.0852 -0.8181
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 995  0.1942  0.3944  0.4610  0.3050  0.2059 -0.0956 -0.2714 -0.0883  1.1763
# 996  0.1942 -0.0321 -0.0286 -0.1828  0.2059  0.7738 -0.2714 -0.0883 -0.8181
# 997  0.1942  0.2356 -0.0342  0.3050  0.2059  0.4101 -0.2714 -0.0883  1.1763
# 998 -0.4726 -0.0321 -0.5861 -0.9968  0.2059  0.4101 -0.2714 -0.0883 -0.8181
# 999  0.1942 -0.3192 -0.0342 -0.9968 -0.3606  0.7738 -0.1396  0.7337 -0.4014
#
#      违约
# 0     0
# 1     1
# 2     0
# 3     0
# 4     1
# ..   ..
# 995   0
# 996   0
# 997   0
# 998   1
# 999   0
#
# [1000 rows x 10 columns]

# %%
#划分数据集
from sklearn.model_selection import train_test_split
X = df_info.iloc[:,:-1]
Y = df_info.iloc[:,-1]
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=110)

# %%
#df_info.iloc[:,-1]

# %%
X_train.head()
# Out:
#          住房    工作年限    财产情况    续存期数    信用额度      目的    储蓄情况    信用记录    账户状态
# 396 -0.4726 -0.3192 -0.5861  0.3050  0.2059 -0.0956 -0.2714 -0.0883 -0.8181
# 263 -0.4726  0.2356 -0.5861  0.3050  0.2059 -0.6061 -0.2714  0.7337  1.1763
# 658  0.1942 -0.0321 -0.0342 -0.1828 -0.3606 -0.2305 -0.2714 -1.3581 -0.4014
# 386 -0.4044 -0.4708  0.4610  0.3050  0.2059  0.4101  0.7042 -0.0883  1.1763
# 988 -0.4726 -0.3192 -0.5861 -0.1828 -0.3606  0.7738 -0.2714 -0.0883 -0.8181

# %%
Y_test.head()
# Out:
# 209    0
# 786    0
# 602    1
# 394    0
# 57     0
# Name: 违约, dtype: int64

# %%
#df_info.iloc[:,:-1]
#df.iloc[:,[-1]]

# %% [markdown]
# ## 建模

# %%
from sklearn.linear_model import LogisticRegression

# %%
#网络搜索查找最优参数
lr_param = {'C': [0.01, 0.1, 0.2, 0.5, 1, 1.5, 2],
                'class_weight': [{1: 1, 0: 1}, {1: 2, 0: 1}, {1: 3, 0: 1}, 'balanced'],
                'max_iter': range(10,100,10)}

# %%
#逻辑回归模型
from sklearn.model_selection import GridSearchCV
lr_gsearch = GridSearchCV(
        estimator=LogisticRegression(random_state=0, fit_intercept=True, penalty='l2'),
        param_grid=lr_param, cv=5, scoring='f1', n_jobs=-1, verbose=2)

# %%
#执行超参数优化 
lr_gsearch.fit(X_train, Y_train)
print('logistic model best_score_ is {0},and best_params_ is {1}'.format(lr_gsearch.best_score_,
                                                                             lr_gsearch.best_params_))
# Out:
# Fitting 5 folds for each of 252 candidates, totalling 1260 fits
# logistic model best_score_ is 0.6265609316246388,and best_params_ is {'C': 1, 'class_weight': 'balanced', 'max_iter': 20}

# %%
#用最优参数，初始化Logistic模型
LR = LogisticRegression(C=lr_gsearch.best_params_['C'], penalty='l2',
                                    class_weight=lr_gsearch.best_params_['class_weight'],
                                    max_iter=lr_gsearch.best_params_['max_iter'])

# %%
#训练Logistic模型
LR = LR.fit(X_train, Y_train)

# %%
#普通的逻辑回归模型
LR = LogisticRegression()
LR.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
#采用变量平衡的逻辑回归模型
LR_b = LogisticRegression(class_weight='balanced') 
LR_b.fit(X_train,Y_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %% [markdown]
# ## 评分卡分数转换

# %%
#系数,即是β1,⋯,βp
LR.coef_[0]
# Out:
# array([-0.61659967, -0.81843063, -0.12581318, -0.68456448, -0.68594508,
#        -0.85880286, -0.62037625, -0.69884219, -0.78128178])

# %%
#截距，即是β0
LR.intercept_
# Out:
# array([-0.83275031])

# %%
X.columns
# Out:
# Index(['住房', '工作年限', '财产情况', '续存期数', '信用额度', '目的', '储蓄情况', '信用记录', '账户状态'], dtype='object')

# %%
def Score(probability):
    score = A-B*np.log(probability/(1-probability))
    return score

#批量获取得分
def List_score(pos_probablity_list):
    list_score=[]
    for probability in pos_probablity_list:
        score=Score(probability)
        list_score.append(score)
    return list_score 

P0 = 600
PDO = 20
theta0 = 1.0/60
B = PDO/np.log(2)
A = P0 + B*np.log(theta0)
print("A:",A)
print("B:",B)
# Out:
# A: 481.8621880878296
# B: 28.85390081777927

# %%
#获取全部X_test数据预测概率
probablity_list=LR_b.predict_proba(X_test)
print('pos_probablity_list\n', probablity_list)
# Out:
# pos_probablity_list
#  [[0.95669163 0.04330837]
#  [0.88418558 0.11581442]
#  [0.13941647 0.86058353]
#  [0.81207718 0.18792282]
#  [0.74619525 0.25380475]
#  [0.690142   0.309858  ]
#  [0.87932488 0.12067512]
#  [0.53433683 0.46566317]
#  [0.51371053 0.48628947]
#  [0.62650733 0.37349267]
#  [0.85609612 0.14390388]
#  [0.59428308 0.40571692]
#  [0.91499402 0.08500598]
#  [0.60219777 0.39780223]
#  [0.51665928 0.48334072]
#  [0.71083902 0.28916098]
#  [0.63410363 0.36589637]
#  [0.1725661  0.8274339 ]
#  [0.75725726 0.24274274]
#  [0.83050851 0.16949149]
#  [0.2290739  0.7709261 ]
#  [0.69078517 0.30921483]
#  [0.60258509 0.39741491]
#  [0.23871503 0.76128497]
#  [0.83110457 0.16889543]
#  [0.47356577 0.52643423]
#  [0.62582201 0.37417799]
#  [0.45194954 0.54805046]
#  [0.65798722 0.34201278]
#  [0.03693118 0.96306882]
#  [0.69972249 0.30027751]
#  [0.80076796 0.19923204]
#  [0.57339644 0.42660356]
#  [0.58063563 0.41936437]
#  [0.89424525 0.10575475]
#  [0.66649919 0.33350081]
#  [0.92323375 0.07676625]
#  [0.69825972 0.30174028]
#  [0.44807039 0.55192961]
#  [0.22763742 0.77236258]
#  [0.71542467 0.28457533]
#  [0.5800242  0.4199758 ]
#  [0.84483155 0.15516845]
#  [0.38638273 0.61361727]
#  [0.52685114 0.47314886]
#  [0.76152948 0.23847052]
#  [0.62544221 0.37455779]
#  [0.31077588 0.68922412]
#  [0.556673   0.443327  ]
#  [0.71733914 0.28266086]
#  [0.48413561 0.51586439]
#  [0.82547949 0.17452051]
#  [0.89045693 0.10954307]
#  [0.84633138 0.15366862]
#  [0.18449111 0.81550889]
#  [0.25453946 0.74546054]
#  [0.85139293 0.14860707]
#  [0.35769403 0.64230597]
#  [0.24427635 0.75572365]
#  [0.72270102 0.27729898]
#  [0.6614125  0.3385875 ]
#  [0.784932   0.215068  ]
#  [0.77368571 0.22631429]
#  [0.20411321 0.79588679]
#  [0.69078517 0.30921483]
#  [0.84975135 0.15024865]
#  [0.18275903 0.81724097]
#  [0.925755   0.074245  ]
#  [0.75523089 0.24476911]
#  [0.60092458 0.39907542]
#  [0.88924062 0.11075938]
#  [0.32640163 0.67359837]
#  [0.90463042 0.09536958]
#  [0.65464152 0.34535848]
#  [0.60940613 0.39059387]
#  [0.38808621 0.61191379]
#  [0.925755   0.074245  ]
#  [0.56291144 0.43708856]
#  [0.5829106  0.4170894 ]
#  [0.25387532 0.74612468]
#  [0.38778508 0.61221492]
#  [0.67236753 0.32763247]
#  [0.8345852  0.1654148 ]
#  [0.22285571 0.77714429]
#  [0.60152103 0.39847897]
#  [0.68619021 0.31380979]
#  [0.36322726 0.63677274]
#  [0.28858176 0.71141824]
#  [0.44897745 0.55102255]
#  [0.4414164  0.5585836 ]
#  [0.80175584 0.19824416]
#  [0.49915698 0.50084302]
#  [0.6240558  0.3759442 ]
#  [0.38624512 0.61375488]
#  [0.02772573 0.97227427]
#  [0.05650998 0.94349002]
#  [0.92386351 0.07613649]
#  [0.72627676 0.27372324]
#  [0.67324988 0.32675012]
#  [0.25759034 0.74240966]
#  [0.50582913 0.49417087]
#  [0.24462647 0.75537353]
#  [0.3550443  0.6449557 ]
#  [0.6005964  0.3994036 ]
#  [0.55688903 0.44311097]
#  [0.88395655 0.11604345]
#  [0.46750083 0.53249917]
#  [0.52467575 0.47532425]
#  [0.32596886 0.67403114]
#  [0.09453628 0.90546372]
#  [0.48647384 0.51352616]
#  [0.62433703 0.37566297]
#  [0.22139138 0.77860862]
#  [0.83620694 0.16379306]
#  [0.73784913 0.26215087]
#  [0.38778508 0.61221492]
#  [0.28606142 0.71393858]
#  [0.7230801  0.2769199 ]
#  [0.92164617 0.07835383]
#  [0.844897   0.155103  ]
#  [0.41032147 0.58967853]
#  [0.48632884 0.51367116]
#  [0.95184828 0.04815172]
#  [0.55657519 0.44342481]
#  [0.88418558 0.11581442]
#  [0.81175735 0.18824265]
#  [0.70041868 0.29958132]
#  [0.58090092 0.41909908]
#  [0.87083666 0.12916334]
#  [0.07212224 0.92787776]
#  [0.39719533 0.60280467]
#  [0.32449239 0.67550761]
#  [0.32807417 0.67192583]
#  [0.1248404  0.8751596 ]
#  [0.18667155 0.81332845]
#  [0.80831201 0.19168799]
#  [0.68233901 0.31766099]
#  [0.93539182 0.06460818]
#  [0.14838156 0.85161844]
#  [0.80067535 0.19932465]
#  [0.77988874 0.22011126]
#  [0.13332714 0.86667286]
#  [0.67405453 0.32594547]
#  [0.71542312 0.28457688]
#  [0.72801509 0.27198491]
#  [0.77967401 0.22032599]
#  [0.35323817 0.64676183]
#  [0.43871942 0.56128058]
#  [0.88418558 0.11581442]
#  [0.33953696 0.66046304]
#  [0.42272879 0.57727121]
#  [0.27605903 0.72394097]
#  [0.40987483 0.59012517]
#  [0.1663896  0.8336104 ]
#  [0.71542312 0.28457688]
#  [0.88002147 0.11997853]
#  [0.45783435 0.54216565]
#  [0.75459039 0.24540961]
#  [0.93895843 0.06104157]
#  [0.70800426 0.29199574]
#  [0.11418768 0.88581232]
#  [0.39874397 0.60125603]
#  [0.92671725 0.07328275]
#  [0.82285667 0.17714333]
#  [0.35817105 0.64182895]
#  [0.56548153 0.43451847]
#  [0.69222316 0.30777684]
#  [0.90203861 0.09796139]
#  [0.38051437 0.61948563]
#  [0.94174834 0.05825166]
#  [0.91193071 0.08806929]
#  [0.63898117 0.36101883]
#  [0.29789902 0.70210098]
#  [0.77967401 0.22032599]
#  [0.87549085 0.12450915]
#  [0.1794195  0.8205805 ]
#  [0.85267419 0.14732581]
#  [0.6570435  0.3429565 ]
#  [0.49915698 0.50084302]
#  [0.58413595 0.41586405]
#  [0.68152878 0.31847122]
#  [0.57265514 0.42734486]
#  [0.39152096 0.60847904]
#  [0.34307444 0.65692556]
#  [0.46807655 0.53192345]
#  [0.61414541 0.38585459]
#  [0.79146876 0.20853124]
#  [0.71079823 0.28920177]
#  [0.65197679 0.34802321]
#  [0.66446561 0.33553439]
#  [0.84243254 0.15756746]
#  [0.64782462 0.35217538]
#  [0.36166848 0.63833152]
#  [0.16183286 0.83816714]
#  [0.56977955 0.43022045]
#  [0.41355415 0.58644585]
#  [0.57320414 0.42679586]
#  [0.46807655 0.53192345]
#  [0.39868357 0.60131643]
#  [0.62665346 0.37334654]]

# %%
#获取全部X_test数据预测为坏用户的概率
pos_probablity_list=LR_b.predict_proba(X_test)[:,1]
print('probablity_list\n', pos_probablity_list)
# Out:
# probablity_list
#  [0.04330837 0.11581442 0.86058353 0.18792282 0.25380475 0.309858
#  0.12067512 0.46566317 0.48628947 0.37349267 0.14390388 0.40571692
#  0.08500598 0.39780223 0.48334072 0.28916098 0.36589637 0.8274339
#  0.24274274 0.16949149 0.7709261  0.30921483 0.39741491 0.76128497
#  0.16889543 0.52643423 0.37417799 0.54805046 0.34201278 0.96306882
#  0.30027751 0.19923204 0.42660356 0.41936437 0.10575475 0.33350081
#  0.07676625 0.30174028 0.55192961 0.77236258 0.28457533 0.4199758
#  0.15516845 0.61361727 0.47314886 0.23847052 0.37455779 0.68922412
#  0.443327   0.28266086 0.51586439 0.17452051 0.10954307 0.15366862
#  0.81550889 0.74546054 0.14860707 0.64230597 0.75572365 0.27729898
#  0.3385875  0.215068   0.22631429 0.79588679 0.30921483 0.15024865
#  0.81724097 0.074245   0.24476911 0.39907542 0.11075938 0.67359837
#  0.09536958 0.34535848 0.39059387 0.61191379 0.074245   0.43708856
#  0.4170894  0.74612468 0.61221492 0.32763247 0.1654148  0.77714429
#  0.39847897 0.31380979 0.63677274 0.71141824 0.55102255 0.5585836
#  0.19824416 0.50084302 0.3759442  0.61375488 0.97227427 0.94349002
#  0.07613649 0.27372324 0.32675012 0.74240966 0.49417087 0.75537353
#  0.6449557  0.3994036  0.44311097 0.11604345 0.53249917 0.47532425
#  0.67403114 0.90546372 0.51352616 0.37566297 0.77860862 0.16379306
#  0.26215087 0.61221492 0.71393858 0.2769199  0.07835383 0.155103
#  0.58967853 0.51367116 0.04815172 0.44342481 0.11581442 0.18824265
#  0.29958132 0.41909908 0.12916334 0.92787776 0.60280467 0.67550761
#  0.67192583 0.8751596  0.81332845 0.19168799 0.31766099 0.06460818
#  0.85161844 0.19932465 0.22011126 0.86667286 0.32594547 0.28457688
#  0.27198491 0.22032599 0.64676183 0.56128058 0.11581442 0.66046304
#  0.57727121 0.72394097 0.59012517 0.8336104  0.28457688 0.11997853
#  0.54216565 0.24540961 0.06104157 0.29199574 0.88581232 0.60125603
#  0.07328275 0.17714333 0.64182895 0.43451847 0.30777684 0.09796139
#  0.61948563 0.05825166 0.08806929 0.36101883 0.70210098 0.22032599
#  0.12450915 0.8205805  0.14732581 0.3429565  0.50084302 0.41586405
#  0.31847122 0.42734486 0.60847904 0.65692556 0.53192345 0.38585459
#  0.20853124 0.28920177 0.34802321 0.33553439 0.15756746 0.35217538
#  0.63833152 0.83816714 0.43022045 0.58644585 0.42679586 0.53192345
#  0.60131643 0.37334654]

# %%
#获取所有x数据的坏客户预测概率
pos_probablity_list=[i[1] for i in probablity_list]
pos_probablity_list
# Out:
# [0.04330837092968998,
#  0.11581442063359097,
#  0.8605835254433225,
#  0.1879228225846488,
#  0.25380474856816365,
#  0.3098579989535778,
#  0.12067512465973897,
#  0.4656631724086704,
#  0.4862894679210038,
#  0.37349266821289556,
#  0.14390388227493817,
#  0.4057169221245572,
#  0.08500598247368102,
#  0.3978022298146514,
#  0.4833407228050901,
#  0.28916098200466905,
#  0.3658963686778107,
#  0.8274339040271027,
#  0.24274273713138678,
#  0.1694914858119119,
#  0.770926096851018,
#  0.30921482711238935,
#  0.3974149070714116,
#  0.7612849733159988,
#  0.1688954262451238,
#  0.5264342345022686,
#  0.3741779885631905,
#  0.5480504585332651,
#  0.3420127829297013,
#  0.9630688221052128,
#  0.300277511700805,
#  0.19923203761045524,
#  0.4266035619887189,
#  0.41936437424340883,
#  0.10575475090060582,
#  0.3335008094338314,
#  0.07676625286948784,
#  0.30174027535212516,
#  0.5519296147877154,
#  0.7723625800442548,
#  0.2845753317067758,
#  0.4199757950069618,
#  0.15516845139639926,
#  0.6136172708720785,
#  0.47314885883277286,
#  0.23847051770589633,
#  0.3745577939765965,
#  0.6892241153977731,
#  0.44332699880733234,
#  0.2826608578597036,
#  0.5158643897019684,
#  0.17452050517582018,
#  0.10954306853779718,
#  0.15366861993901548,
#  0.8155088903027897,
#  0.7454605382287208,
#  0.148607071098802,
#  0.6423059718727548,
#  0.755723654397896,
#  0.2772989836182961,
#  0.3385875039675454,
#  0.2150680048009523,
#  0.2263142942302195,
#  0.7958867877334644,
#  0.30921482711238935,
#  0.15024864754796788,
#  0.8172409743688455,
#  0.07424500049620532,
#  0.2447691137065257,
#  0.39907541895594867,
#  0.11075937603235299,
#  0.6735983690797882,
#  0.09536957686785406,
#  0.345358484009462,
#  0.39059387367687104,
#  0.6119137878620913,
#  0.07424500049620532,
#  0.4370885633518515,
#  0.41708940487289975,
#  0.7461246809461363,
#  0.6122149190408547,
#  0.3276324662510777,
#  0.16541479951620383,
#  0.7771442909227918,
#  0.3984789678695848,
#  0.31380978717612723,
#  0.6367727377443955,
#  0.7114182391867633,
#  0.5510225487980073,
#  0.5585835983536924,
#  0.19824416357532865,
#  0.5008430203789476,
#  0.3759442030008048,
#  0.613754875481414,
#  0.9722742666466049,
#  0.9434900223422624,
#  0.07613649173121953,
#  0.2737232435916209,
#  0.3267501208671058,
#  0.74240965783268,
#  0.49417086594492765,
#  0.7553735283831868,
#  0.6449557025722077,
#  0.39940359583861906,
#  0.4431109688275357,
#  0.11604345433511282,
#  0.5324991708333391,
#  0.4753242451518614,
#  0.6740311428873473,
#  0.9054637180295384,
#  0.513526159349013,
#  0.37566296890488493,
#  0.7786086236723685,
#  0.16379306182053632,
#  0.2621508654907879,
#  0.6122149190408547,
#  0.7139385761376165,
#  0.2769199030969606,
#  0.07835383355741986,
#  0.15510300219463674,
#  0.5896785313145175,
#  0.5136711583447366,
#  0.04815171863219705,
#  0.44342480787540445,
#  0.11581442063359097,
#  0.18824264774579422,
#  0.2995813233414598,
#  0.4190990835823902,
#  0.1291633413942451,
#  0.9278777613698277,
#  0.6028046718585969,
#  0.6755076064815669,
#  0.6719258265174165,
#  0.875159601444706,
#  0.8133284473424289,
#  0.19168799035022904,
#  0.3176609893536728,
#  0.06460817741652082,
#  0.8516184401893762,
#  0.19932465403887292,
#  0.22011126439856446,
#  0.8666728586488947,
#  0.32594547468528456,
#  0.28457688287378347,
#  0.27198490952250154,
#  0.22032599228176325,
#  0.6467618288665746,
#  0.5612805820437214,
#  0.11581442063359097,
#  0.660463035786162,
#  0.5772712075260018,
#  0.7239409696132009,
#  0.5901251668730226,
#  0.8336103987864585,
#  0.28457688287378347,
#  0.11997853067184083,
#  0.5421656466860881,
#  0.24540960632914166,
#  0.06104157416357587,
#  0.29199574086048896,
#  0.8858123173426442,
#  0.601256030480679,
#  0.07328275019802608,
#  0.1771433286880432,
#  0.6418289515333998,
#  0.43451847013953554,
#  0.3077768399194516,
#  0.09796138699185951,
#  0.6194856313904621,
#  0.058251658551501585,
#  0.08806929147335976,
#  0.36101883351114133,
#  0.7021009765933265,
#  0.22032599228176325,
#  0.1245091506993377,
#  0.8205804963663784,
#  0.14732580667783962,
#  0.34295649599632594,
#  0.5008430203789476,
#  0.415864053582123,
#  0.31847121753000707,
#  0.4273448569565978,
#  0.6084790382418426,
#  0.6569255585199679,
#  0.531923452790891,
#  0.38585458974558107,
#  0.20853124293219535,
#  0.2892017670390974,
#  0.3480232148490681,
#  0.3355343860760911,
#  0.1575674554572009,
#  0.35217538219561634,
#  0.638331519912627,
#  0.8381671371821409,
#  0.43022044729120845,
#  0.5864458508786545,
#  0.426795857383612,
#  0.531923452790891,
#  0.6013164317304786,
#  0.37334654375022386]

# %%
#获得所有客户的分数
list_score=List_score(pos_probablity_list)
list_predict=LR_b.predict(X_test)

# %%
#分数取整
list_score = [round(i) for i in list_score]
list_score
# Out:
# [571,
#  541,
#  429,
#  524,
#  513,
#  505,
#  539,
#  486,
#  483,
#  497,
#  533,
#  493,
#  550,
#  494,
#  484,
#  508,
#  498,
#  437,
#  515,
#  528,
#  447,
#  505,
#  494,
#  448,
#  528,
#  479,
#  497,
#  476,
#  501,
#  388,
#  506,
#  522,
#  490,
#  491,
#  543,
#  502,
#  554,
#  506,
#  476,
#  447,
#  508,
#  491,
#  531,
#  469,
#  485,
#  515,
#  497,
#  459,
#  488,
#  509,
#  480,
#  527,
#  542,
#  531,
#  439,
#  451,
#  532,
#  465,
#  449,
#  510,
#  501,
#  519,
#  517,
#  443,
#  505,
#  532,
#  439,
#  555,
#  514,
#  494,
#  542,
#  461,
#  547,
#  500,
#  495,
#  469,
#  555,
#  489,
#  492,
#  451,
#  469,
#  503,
#  529,
#  446,
#  494,
#  504,
#  466,
#  456,
#  476,
#  475,
#  522,
#  482,
#  496,
#  468,
#  379,
#  401,
#  554,
#  510,
#  503,
#  451,
#  483,
#  449,
#  465,
#  494,
#  488,
#  540,
#  478,
#  485,
#  461,
#  417,
#  480,
#  497,
#  446,
#  529,
#  512,
#  469,
#  455,
#  510,
#  553,
#  531,
#  471,
#  480,
#  568,
#  488,
#  541,
#  524,
#  506,
#  491,
#  537,
#  408,
#  470,
#  461,
#  461,
#  426,
#  439,
#  523,
#  504,
#  559,
#  431,
#  522,
#  518,
#  428,
#  503,
#  508,
#  510,
#  518,
#  464,
#  475,
#  541,
#  463,
#  473,
#  454,
#  471,
#  435,
#  508,
#  539,
#  477,
#  514,
#  561,
#  507,
#  423,
#  470,
#  555,
#  526,
#  465,
#  489,
#  505,
#  546,
#  468,
#  562,
#  549,
#  498,
#  457,
#  518,
#  538,
#  438,
#  533,
#  501,
#  482,
#  492,
#  504,
#  490,
#  469,
#  463,
#  478,
#  495,
#  520,
#  508,
#  500,
#  502,
#  530,
#  499,
#  465,
#  434,
#  490,
#  472,
#  490,
#  478,
#  470,
#  497]

# %%
#构造dataframe
df_results = pd.DataFrame({'label':Y_test,'predict':list_predict,
                           'pos_probablity_list':pos_probablity_list,
                           'score':list_score})

# %%
#结果写入excel
df_results.to_excel('score_proba.xlsx')

# %%
tar
# Out:
# ['住房', '工作年限', '财产情况', '续存期数', '信用额度', '目的', '储蓄情况', '信用记录', '账户状态', '违约']

# %%
tar.pop() #去除引入的目标变量‘违约’
tar
# Out:
# ['住房', '工作年限', '财产情况', '续存期数', '信用额度', '目的', '储蓄情况', '信用记录', '账户状态']

# %%
beta_lt = LR.coef_[0] 
beta_lt
# Out:
# array([-0.61659967, -0.81843063, -0.12581318, -0.68456448, -0.68594508,
#        -0.85880286, -0.62037625, -0.69884219, -0.78128178])

# %%
#获得各特征变量各分箱的woe值
woedict = {}
for var_ in tar:
    woedict[var_] = WOE(var_,df)[0]
woedict
# Out:
# {'住房': {'A152': 0.19415601444095756,
#   'A153': -0.4726044109457929,
#   'A151': -0.4044452202074189},
#  '工作年限': {'A75': 0.2355660713127669,
#   'A73': -0.03210324538441743,
#   'A74': 0.39441527192157944,
#   'A71': -0.3192304301867068,
#   'A72': -0.4708202891522916},
#  '财产情况': {'A121': 0.46103495926297494,
#   'A122': -0.028573372444056,
#   'A124': -0.5860823611235859,
#   'A123': -0.034191364748279426},
#  '续存期数': {'0': 0.30498584507342397,
#   '2': -0.9968295943581674,
#   '1': -0.18278249250158538,
#   '3': -0.8472978603872037},
#  '信用额度': {'0': 0.20585205420414882,
#   '1': -0.36064259754902595,
#   '2': -0.8064758658669485,
#   '3': -1.6357552207514738,
#   '4': -1.252762968495368},
#  '目的': {'A43': 0.41006281735679384,
#   'A46': -0.6061358035703156,
#   'A42': -0.0955565155612054,
#   'A40': -0.359200487698769,
#   'A41': 0.7738360918100882,
#   'A49': -0.23052365861183224,
#   'A44': -0.15415067982725836,
#   'A45': -0.2876820724517809,
#   'A410': -0.5108256237659907,
#   'A48': 1.2321436812926323},
#  '储蓄情况': {'A65': 0.7042460736279941,
#   'A61': -0.2713578444628324,
#   'A63': 0.7060505853958533,
#   'A64': 1.0986122886681098,
#   'A62': -0.1395518804061056},
#  '信用记录': {'A34': 0.733740577525199,
#   'A32': -0.08831861697739624,
#   'A33': -0.08515780834030683,
#   'A30': -1.3581234841531942,
#   'A31': -1.1349799328389847},
#  '账户状态': {'A11': -0.8180987056949414,
#   'A12': -0.4013917827205285,
#   'A14': 1.176263222898176,
#   'A13': 0.4054651081081644}}

# %%
tar
# Out:
# ['住房', '工作年限', '财产情况', '续存期数', '信用额度', '目的', '储蓄情况', '信用记录', '账户状态']

# %%
#woedict_={}
#for a in woedict:
#    if a in tar:
#        woedict_[a] = woedict[a]
#woedict_

# %%
beta_lt
# Out:
# array([-0.61659967, -0.81843063, -0.12581318, -0.68456448, -0.68594508,
#        -0.85880286, -0.62037625, -0.69884219, -0.78128178])

# %%
#评分卡转换
i=-1
k=0 #计数行，用于append进df1
df1 = pd.DataFrame(columns=['变量','类别','分数'])  #新建dataframe
for var in woedict.items():    
    #var[0] :变量
    #var[1] :变量的woe字典
    i+=1
    for temp in var[1].keys():
        
        #var[1][temp] :变量内各个分箱的woe值
        #beta_lt[i] :各个变量对应的beta值
        point = -(B * beta_lt[i] * var[1][temp]) #计算变量分箱的评分
        point = round(point)                   #取整
        df1.loc[k] = [var[0],temp,point]         #写入dataframe
        k+=1   #行定位下移

# %%
df1.head()
# Out:
#      变量    类别  分数
# 0    住房  A152   3
# 1    住房  A153  -8
# 2    住房  A151  -7
# 3  工作年限   A75   6
# 4  工作年限   A73  -1

# %%
df1.to_excel('5.2German信用评分卡(LR,iv大于0.08).xlsx')

# %%
A - B * (beta_lt[1]*0.0005250722094907142+beta_lt[0])
# Out:
# 499.6658932686126

# %%
beta0 = LR.intercept_[0]

# %%
print(f'基础分数：{round(A-beta0*B)}')
# Out:
# 基础分数：506

# %% [markdown]
# ## 模型评价

# %%
#分类模型评价
from sklearn.metrics import classification_report
#混淆矩阵
from sklearn.metrics import confusion_matrix
#roc,P-R
from sklearn.metrics import roc_curve,auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### LR

# %%
print(f"逻辑回归的准确率：{(round(LR.score(X_test,Y_test),4))*100}%")
# Out:
# 逻辑回归的准确率：79.5%

# %%
#普通逻辑回归模型的评价
print(f"模型评价:\n{classification_report(Y,LR.predict(X))}")
# Out:
# 模型评价:
#               precision    recall  f1-score   support
#
#            0       0.78      0.91      0.84       700
#            1       0.65      0.41      0.50       300
#
#     accuracy                           0.76      1000
#    macro avg       0.72      0.66      0.67      1000
# weighted avg       0.74      0.76      0.74      1000

# %%
#混淆矩阵
cnf_matrix = confusion_matrix(Y,LR.predict(X))
print('混淆矩阵：\n',cnf_matrix)
# Out:
# 混淆矩阵：
#  [[635  65]
#  [177 123]]

# %%
sns.heatmap(cnf_matrix,annot=True,cmap=plt.cm.Blues,fmt='g')
plt.title('模型混淆矩阵的热力图')
plt.show()

# %%
#ROC曲线和P-R曲线
#FTR:假阳性率，TPR：真阳性率
FPR,TPR,thresholds = roc_curve(Y,LR.predict_proba(X)[:,1],pos_label=1)
roc_auc = auc(FPR,TPR)  #auc值
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
plt.plot(FPR,TPR,color = 'r',linewidth=2,label=f'ROC curve={roc_auc}')
plt.plot([0,1],[0,1],color='k',linewidth=1,linestyle='--')
plt.xlim([-0.001,1.01])
plt.ylim([-0.001,1.01])
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC曲线')
plt.legend(loc = 'best')

plt.subplot(1,2,2)
PRE,REC,thresholds = precision_recall_curve(Y,LR.predict_proba(X)[:,1],pos_label=1)
plt.plot(REC,PRE,color = 'r',linewidth=2,label=f'总正确率={accuracy_score(Y,LR.predict(X))}')
plt.plot([0,1],[1,PRE.min()],color='k',linewidth=1,linestyle='--')
plt.xlim([-0.001,1.01])
plt.ylim([PRE.min()-0.001,1.01])
plt.xlabel('查全率R')
plt.ylabel('查准率P')
plt.title('P-R曲线')
plt.legend(loc = 'best')
plt.show()

print("AUC为：",roc_auc)
print("总准确率为：",accuracy_score(Y,LR.predict(X)))
# Out:
# AUC为： 0.8053666666666667
# 总准确率为： 0.758

# %% [markdown]
# ### LR_b(样本平衡的)

# %%
print(f"逻辑回归的准确率：{(round(LR_b.score(X_test,Y_test),4))*100}%")
# Out:
# 逻辑回归的准确率：75.0%

# %%
#采用变量平衡的逻辑回归模型的评价
print(f"模型评价:\n{classification_report(Y,LR_b.predict(X))}")
# Out:
# 模型评价:
#               precision    recall  f1-score   support
#
#            0       0.87      0.72      0.79       700
#            1       0.53      0.76      0.63       300
#
#     accuracy                           0.73      1000
#    macro avg       0.70      0.74      0.71      1000
# weighted avg       0.77      0.73      0.74      1000

# %%
#混淆矩阵
cnf_matrix = confusion_matrix(Y,LR_b.predict(X))
print('混淆矩阵：\n',cnf_matrix)
# Out:
# 混淆矩阵：
#  [[501 199]
#  [ 73 227]]

# %%
sns.heatmap(cnf_matrix,annot=True,cmap=plt.cm.Blues,fmt='g')
plt.title('模型混淆矩阵的热力图')
plt.show()

# %%
#ROC曲线和P-R曲线
#FTR:假阳性率，TPR：真阳性率
FPR,TPR,thresholds = roc_curve(Y,LR_b.predict_proba(X)[:,1],pos_label=1)
roc_auc = auc(FPR,TPR)  #auc值
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
plt.plot(FPR,TPR,color = 'r',linewidth=2,label=f'ROC curve={roc_auc}')
plt.plot([0,1],[0,1],color='k',linewidth=1,linestyle='--')
plt.xlim([-0.001,1.01])
plt.ylim([-0.001,1.01])
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC曲线')
plt.legend(loc = 'best')

plt.subplot(1,2,2)
PRE,REC,thresholds = precision_recall_curve(Y,LR_b.predict_proba(X)[:,1],pos_label=1)
plt.plot(REC,PRE,color = 'r',linewidth=2,label=f'总正确率={accuracy_score(Y,LR_b.predict(X))}')
plt.plot([0,1],[1,PRE.min()],color='k',linewidth=1,linestyle='--')
plt.xlim([-0.001,1.01])
plt.ylim([PRE.min()-0.001,1.01])
plt.xlabel('查全率R')
plt.ylabel('查准率P')
plt.title('P-R曲线')
plt.legend(loc = 'best')
plt.show()

print("AUC为：",roc_auc)
print("总准确率为：",accuracy_score(Y,LR_b.predict(X)))
# Out:
# AUC为： 0.8057619047619047
# 总准确率为： 0.728

# %% [markdown]
# ## (LR_b模型)评分卡分数转换

# %%
#系数,即是β1,⋯,βp
LR_b.coef_[0]
# Out:
# array([-0.64521407, -0.94071371, -0.10364738, -0.73151993, -0.77521383,
#        -0.96191618, -0.52434953, -0.7237851 , -0.80315633])

# %%
#截距，即是β0
LR_b.intercept_
# Out:
# array([-0.01782762])

# %%
beta0 = LR_b.intercept_[0]

# %%
print(f'基础分数：{round(A-beta0*B)}')
# Out:
# 基础分数：482

# %%
#系数,即是β1,⋯,βp
beta_lt_b = LR_b.coef_[0] 
beta_lt_b
# Out:
# array([-0.64521407, -0.94071371, -0.10364738, -0.73151993, -0.77521383,
#        -0.96191618, -0.52434953, -0.7237851 , -0.80315633])

# %%
#评分卡转换
i=-1
k=0 #计数行，用于append进df1
df2 = pd.DataFrame(columns=['变量','类别','分数'])  #新建dataframe
for var in woedict.items():    
    #var[0] :变量
    #var[1] :变量的woe字典
    i+=1
    for temp in var[1].keys():
        
        #var[1][temp] :变量内各个分箱的woe值
        #beta_lt[i] :各个变量对应的beta值
        point = -(B * beta_lt_b[i] * var[1][temp]) #计算变量分箱的评分
        point = round(point)                   #取整
        df2.loc[k] = [var[0],temp,point]         #写入dataframe
        k+=1   #行定位下移

# %%
df2
# Out:
#       变量    类别  分数
# 0     住房  A152   4
# 1     住房  A153  -9
# 2     住房  A151  -8
# 3   工作年限   A75   6
# 4   工作年限   A73  -1
# 5   工作年限   A74  11
# 6   工作年限   A71  -9
# 7   工作年限   A72 -13
# 8   财产情况  A121   1
# 9   财产情况  A122   0
# 10  财产情况  A124  -2
# 11  财产情况  A123   0
# 12  续存期数     0   6
# 13  续存期数     2 -21
# 14  续存期数     1  -4
# 15  续存期数     3 -18
# 16  信用额度     0   5
# 17  信用额度     1  -8
# 18  信用额度     2 -18
# 19  信用额度     3 -37
# 20  信用额度     4 -28
# 21    目的   A43  11
# 22    目的   A46 -17
# 23    目的   A42  -3
# 24    目的   A40 -10
# 25    目的   A41  21
# 26    目的   A49  -6
# 27    目的   A44  -4
# 28    目的   A45  -8
# 29    目的  A410 -14
# 30    目的   A48  34
# 31  储蓄情况   A65  11
# 32  储蓄情况   A61  -4
# 33  储蓄情况   A63  11
# 34  储蓄情况   A64  17
# 35  储蓄情况   A62  -2
# 36  信用记录   A34  15
# 37  信用记录   A32  -2
# 38  信用记录   A33  -2
# 39  信用记录   A30 -28
# 40  信用记录   A31 -24
# 41  账户状态   A11 -19
# 42  账户状态   A12  -9
# 43  账户状态   A14  27
# 44  账户状态   A13   9

# %%
df2.to_excel('German信用评分卡(iv大于0.8,LR_b平衡).xlsx')
